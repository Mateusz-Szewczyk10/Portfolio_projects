# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/polish_gdp.csv",skiprows=4)

# %%
df[df["Country Name"]=="Poland"].T[4:-1]
# Out:
#                       190
# 1960                  NaN
# 1961                  NaN
# 1962                  NaN
# 1963                  NaN
# 1964                  NaN
# ...                   ...
# 2018  588779850758.052979
# 2019  596058473058.765991
# 2020  599442783598.063965
# 2021   681346136411.70105
# 2022   688125010520.52002
#
# [63 rows x 1 columns]

# %%
sns.lineplot(df[df["Country Name"]=="Poland"].T[4:-1])
plt.title("Polish GDP over time")
plt.xticks(rotation=90)
plt.show()

# %%
net_migration = pd.read_csv("data/API_SM.POP.NETM_DS2_en_csv_v2_6299839.csv", skiprows=4)

# %%
pl_net_mig = net_migration[net_migration["Country Name"] == "Poland"].T[4:-1]
pl_net_mig
# Out:
#           190
# 1960 -20564.0
# 1961 -20143.0
# 1962 -23676.0
# 1963 -19321.0
# 1964 -19967.0
# ...       ...
# 2018  -8736.0
# 2019  -2974.0
# 2020   -779.0
# 2021  -2968.0
# 2022      NaN
#
# [63 rows x 1 columns]

# %%
sns.lineplot(pl_net_mig)
plt.axvline(x="2004")

# %%
final = pd.concat([df[df["Country Name"]=="Poland"].T[4:-1], pl_net_mig], axis=1)

# %%
final.columns = ["GDP", "Net migration"]

# %%
final
# Out:
#                       GDP Net migration
# 1960                  NaN      -20564.0
# 1961                  NaN      -20143.0
# 1962                  NaN      -23676.0
# 1963                  NaN      -19321.0
# 1964                  NaN      -19967.0
# ...                   ...           ...
# 2018  588779850758.052979       -8736.0
# 2019  596058473058.765991       -2974.0
# 2020  599442783598.063965        -779.0
# 2021   681346136411.70105       -2968.0
# 2022   688125010520.52002           NaN
#
# [63 rows x 2 columns]
