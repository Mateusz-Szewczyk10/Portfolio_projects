# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data/polish_gdp.csv",skiprows=4)

# %%
df[df["Country Name"]=="Poland"].T[4:]
# Out:
#                              190
# 1960                         NaN
# 1961                         NaN
# 1962                         NaN
# 1963                         NaN
# 1964                         NaN
# ...                          ...
# 2019         596058473058.765991
# 2020         599442783598.063965
# 2021          681346136411.70105
# 2022          688125010520.52002
# Unnamed: 67                  NaN
#
# [64 rows x 1 columns]

# %%
sns.lineplot(df[df["Country Name"]=="Poland"].T[4:])
# Out:
# <Axes: >
